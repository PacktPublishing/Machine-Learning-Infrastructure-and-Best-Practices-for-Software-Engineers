# %% [markdown]
# # Word piece tokenizer example
#
# This example shows how to use a more advanced tokenizer based on word pieces.
#
# The tokenizer finds subsets of words that can be used as tokens.

# %%
# !pip install -q tokenizers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 47.6 MB/s eta 0:00:00

# %%
from tokenizers import BertWordPieceTokenizer

# initialize the actual tokenizer
tokenizer = BertWordPieceTokenizer(
    clean_text=True,
    handle_chinese_chars=False,
    strip_accents=False,
    lowercase=True
)

# %%
# now, we need to prepare a dataset
# in our case, let's just read a dataset that is a code of a program

# in this example, I use the file from an open source component - Azure NetX
# the actual part is not that important, as long as we have a set of 
# tokens that we want to analyze
paths = './nx_icmp_checksum_compute.c'

# %%
# and train the tokenizer based on the text
tokenizer.train(files=paths, 
                vocab_size=30_000, 
                min_frequency=1,
                limit_alphabet=1000, 
                wordpieces_prefix='##',
                special_tokens=['[PAD', '[UNK]', '[CLS]', '[SEP]', '[MASK]'])

# %%
tokenizer.get_vocab()
# Out:
# {'##ll': 183,
#  'disable': 326,
#  'al': 263,
#  '##cket': 90,
#  '##s': 65,
#  'computed': 484,
#  'is': 178,
#  '##ure': 309,
#  '09': 357,
#  'po': 151,
#  'so': 400,
#  'upper': 345,
#  '##ic': 136,
#  '##sion': 296,
#  '##2': 84,
#  '##it': 152,
#  'lic': 197,
#  '##n': 68,
#  'all': 366,
#  '##v': 80,
#  'wor': 108,
#  'uchar': 226,
#  '##6': 82,
#  '9': 24,
#  'cal': 267,
#  'be': 367,
#  'aka': 505,
#  'previous': 546,
#  'ma': 272,
#  'date': 376,
#  'boundary': 506,
#  'pa': 89,
#  'case': 374,
#  'word': 109,
#  '##ter': 141,
#  '##xt': 186,
#  'ul': 127,
#  'det': 196,
#  'output': 521,
#  '##te': 115,
#  'shi': 233,
#  'swap': 321,
#  '##ig': 239,
#  '##tocol': 476,
#  'bit': 172,
#  '##ly': 439,
#  'swa': 202,
#  'move': 253,
#  'else': 336,
#  'generates': 548,
#  'car': 372,
#  'new': 473,
#  'alignment': 333,
#  'include': 261,
#  'z': 53,
#  '2': 20,
#  'set': 232,
#  'calcul': 493,
#  '##ort': 125,
#  'ptr': 105,
#  'az': 264,
#  '##wer': 187,
#  '##ur': 111,
#  '##cre': 300,
#  '##cl': 243,
#  'pro': 393,
#  '##p': 59,
#  'hi': 383,
#  'found': 380,
#  'lower': 193,
#  'do': 375,
#  'pi': 276,
#  '##ent': 119,
#  'we': 181,
#  'portable': 522,
#  'source': 528,
#  '}': 56,
#  'previou': 489,
#  '##x': 77,
#  '##op': 418,
#  '3': 21,
#  '##ry': 422,
#  '##cul': 435,
#  '##re': 124,
#  'calculate': 547,
#  'off': 466,
#  'func': 328,
#  'le': 270,
#  'mask': 194,
#  '##h': 64,
#  '##ting': 415,
#  '=': 27,
#  'mes': 273,
#  '##mp': 106,
#  'de': 159,
#  '##hort': 128,
#  'will': 347,
#  'checksu': 101,
#  '##a': 73,
#  '##g': 63,
#  "'": 9,
#  '##en': 93,
#  'bound': 368,
#  'name': 517,
#  'bits': 219,
#  '(': 10,
#  '##hi': 164,
#  'short': 201,
#  '##thor': 461,
#  '##c': 69,
#  'none': 341,
#  '##t': 57,
#  'ret': 277,
#  'yu': 236,
#  '##ignment': 330,
#  'mas': 180,
#  'endian': 156,
#  '05': 356,
#  'full': 488,
#  'again': 503,
#  'ch': 265,
#  'ha': 269,
#  'rou': 396,
#  ':': 25,
#  'icmp': 138,
#  '##ste': 427,
#  'this': 257,
#  '##rs': 423,
#  '##se': 118,
#  '##right': 482,
#  'ver': 280,
#  'start': 527,
#  'defined': 331,
#  'ne': 150,
#  'function': 353,
#  '##dified': 444,
#  'zhou': 259,
#  '##ption': 288,
#  '##ize': 158,
#  'the': 92,
#  'version': 346,
#  'ap': 360,
#  'history': 515,
#  'ro': 394,
#  'fi': 228,
#  'append': 222,
#  'api': 502,
#  'nx': 95,
#  '##net': 432,
#  '##he': 87,
#  '##es': 241,
#  '##9': 81,
#  'i': 38,
#  '##ht': 294,
#  'ca': 369,
#  'control': 508,
#  'internet': 541,
#  '##o': 58,
#  '5': 22,
#  'return': 343,
#  'op': 389,
#  '##wa': 166,
#  '##ow': 419,
#  '##sage': 324,
#  'h': 37,
#  'neces': 474,
#  '!': 5,
#  'eul': 377,
#  '##ware': 252,
#  ';': 26,
#  '##sary': 428,
#  't': 47,
#  'initialize': 501,
#  '##sable': 325,
#  're': 200,
#  '##ase': 185,
#  'port': 392,
#  '##cture': 438,
#  '##ul': 244,
#  'author': 504,
#  'in': 110,
#  '##ing': 190,
#  '0': 18,
#  '{': 54,
#  'http': 514,
#  'd': 33,
#  '_': 29,
#  '##l': 70,
#  'l': 40,
#  'need': 315,
#  'rights': 526,
#  'specified': 355,
#  '##ion': 291,
#  'add': 171,
#  '##de': 211,
#  '##ve': 188,
#  '##ermine': 220,
#  'ov': 390,
#  '#': 7,
#  '##ti': 134,
#  '##ole': 420,
#  '##ght': 425,
#  '##ary': 316,
#  '##su': 98,
#  '##hts': 499,
#  'byte': 191,
#  'n': 42,
#  'input': 307,
#  '|': 55,
#  '##ound': 319,
#  '##ute': 210,
#  'st': 399,
#  'two': 533,
#  'swapping': 322,
#  '##iz': 153,
#  'len': 114,
#  'whole': 537,
#  'con': 370,
#  '##sed': 462,
#  'supplied': 530,
#  'syste': 529,
#  '20': 262,
#  'spec': 344,
#  'temp': 147,
#  'determine': 223,
#  '##ture': 416,
#  '[UNK]': 1,
#  'mul': 386,
#  'modified': 479,
#  'sing': 404,
#  'pre': 231,
#  'corpor': 335,
#  'und': 409,
#  'single': 532,
#  '##lied': 440,
#  'wi': 281,
#  '##pp': 143,
#  '##sulting': 456,
#  '##as': 145,
#  'uin': 408,
#  '##pplied': 467,
#  'message': 340,
#  'packet': 91,
#  '##lls': 477,
#  'initial': 350,
#  '##i': 62,
#  '##har': 207,
#  '##to': 182,
#  'logic': 314,
#  'azure': 491,
#  '##ri': 204,
#  'loop': 472,
#  'te': 133,
#  '##tine': 414,
#  'ht': 382,
#  '##ange': 312,
#  '##f': 76,
#  '##sa': 208,
#  'app': 195,
#  'at': 176,
#  'under': 536,
#  'an': 362,
#  '[CLS]': 2,
#  '##ain': 445,
#  'fro': 379,
#  'corporation': 354,
#  'can': 371,
#  'mic': 199,
#  'g': 36,
#  'comment': 471,
#  'm': 41,
#  'y': 52,
#  '##py': 421,
#  'computes': 483,
#  '##ment': 242,
#  '##5': 79,
#  '##ble': 249,
#  'next': 217,
#  '##ense': 214,
#  '[SEP]': 3,
#  '##an': 129,
#  'cur': 131,
#  'prepend': 329,
#  'if': 126,
#  'rx': 395,
#  'def': 251,
#  'p': 44,
#  'wri': 412,
#  '##al': 212,
#  '##e': 66,
#  '##lting': 441,
#  'calls': 507,
#  '##tor': 283,
#  'file': 327,
#  '##le': 121,
#  'ushort': 170,
#  '##on': 97,
#  'called': 494,
#  '##erflow': 454,
#  '/': 17,
#  'padding': 540,
#  'last': 230,
#  'generate': 513,
#  'uint': 535,
#  'reser': 480,
#  'compute': 221,
#  '##os': 142,
#  'out': 391,
#  '>': 28,
#  'tw': 406,
#  '##iou': 424,
#  'w': 50,
#  'are': 365,
#  'net': 388,
#  '##pping': 313,
#  '##ast': 216,
#  'c': 32,
#  'setup': 254,
#  '19': 358,
#  '##ined': 306,
#  'u': 48,
#  '##urn': 310,
#  'pointer': 157,
#  'lo': 149,
#  '2020': 332,
#  '##z': 74,
#  'license': 224,
#  '-': 15,
#  '##low': 442,
#  '##tp': 413,
#  'v': 49,
#  'b': 31,
#  '##able': 446,
#  'us': 161,
#  'na': 387,
#  's': 46,
#  '[PAD': 0,
#  'checksum': 102,
#  'change': 334,
#  'copyright': 542,
#  '##cros': 301,
#  'microsoft': 225,
#  '##xin': 248,
#  'description': 351,
#  '##pend': 289,
#  '##ed': 144,
#  '##tr': 103,
#  'https': 549,
#  '##cksu': 100,
#  'non': 274,
#  'fu': 229,
#  'first': 545,
#  '##th': 113,
#  'decre': 318,
#  'incl': 250,
#  '##tory': 349,
#  '##ce': 433,
#  'sp': 278,
#  '##erate': 451,
#  'su': 402,
#  '##w': 78,
#  '+': 13,
#  '##tle': 284,
#  '##er': 96,
#  'initi': 308,
#  'of': 140,
#  '##u': 71,
#  '##ine': 175,
#  'che': 99,
#  'r': 45,
#  '##k': 75,
#  '##rosoft': 218,
#  'current': 137,
#  'shift': 255,
#  '##ec': 297,
#  '##ation': 247,
#  '##r': 61,
#  'inter': 458,
#  'pickup': 342,
#  'little': 338,
#  '##y': 60,
#  'long': 179,
#  'these': 304,
#  '"': 6,
#  'term': 407,
#  '##trol': 457,
#  '##put': 238,
#  'upp': 279,
#  '##ctory': 437,
#  '##ude': 245,
#  'o': 43,
#  '##d': 72,
#  '##ied': 205,
#  '*': 12,
#  '##ou': 162,
#  '&': 8,
#  'routines': 550,
#  '##eration': 452,
#  'comp': 192,
#  '##ut': 209,
#  '##ces': 434,
#  'endif': 468,
#  '##et': 88,
#  '##in': 104,
#  'zer': 282,
#  '##erm': 189,
#  'least': 496,
#  'terms': 534,
#  'zero': 348,
#  '##ro': 290,
#  'text': 465,
#  'str': 403,
#  'licensed': 485,
#  'thi': 235,
#  '##up': 184,
#  'into': 215,
#  'to': 173,
#  'gen': 381,
#  '##ar': 154,
#  'for': 378,
#  '##me': 430,
#  'rig': 397,
#  'root': 524,
#  'cros': 373,
#  'whi': 411,
#  'it': 384,
#  'have': 337,
#  '##of': 116,
#  'zh': 237,
#  'reserved': 544,
#  '##inter': 155,
#  'files': 500,
#  'structure': 531,
#  '##nment': 299,
#  '##ertos': 453,
#  'operation': 519,
#  'copy': 470,
#  'padd': 450,
#  'routine': 525,
#  '##lease': 311,
#  'macros': 339,
#  '##ot': 417,
#  'au': 363,
#  'overflow': 520,
#  '##0': 83,
#  'crossed': 510,
#  '##ate': 246,
#  '##flow': 447,
#  '##onent': 455,
#  'azurertos': 492,
#  '##ft': 213,
#  'yuxin': 258,
#  '30': 359,
#  ')': 11,
#  '##iti': 292,
#  'protocol': 523,
#  '##ckup': 303,
#  ',': 14,
#  '##tion': 168,
#  '##end': 174,
#  'co': 148,
#  '##b': 85,
#  '##ser': 426,
#  'wh': 410,
#  'e': 34,
#  '##gic': 293,
#  'sizeof': 169,
#  'multi': 516,
#  '##ucture': 443,
#  '##m': 67,
#  '##art': 475,
#  'netx': 518,
#  '##ified': 260,
#  'carry': 509,
#  '.': 16,
#  'el': 268,
#  '[MASK]': 4,
#  'ak': 364,
#  'decrease': 352,
#  'mo': 198,
#  'length': 120,
#  'x': 51,
#  '##ros': 163,
#  'resulting': 481,
#  '##tos': 285,
#  '##if': 240,
#  '##led': 463,
#  '##ck': 86,
#  'endi': 146,
#  '##ge': 206,
#  'end': 123,
#  '1': 19,
#  '##ol': 286,
#  'define': 490,
#  '##ong': 112,
#  'size': 160,
#  'there': 305,
#  'uc': 203,
#  'left': 495,
#  'from': 512,
#  'component': 478,
#  'ag': 361,
#  'ulong': 130,
#  'and': 177,
#  'ic': 132,
#  'code': 469,
#  'by': 139,
#  'desc': 317,
#  '##col': 436,
#  'di': 227,
#  '##nc': 298,
#  'firs': 487,
#  '##story': 429,
#  '##nd': 107,
#  'k': 39,
#  'while': 538,
#  '##por': 287,
#  'one': 497,
#  '##or': 94,
#  '##urertos': 460,
#  '##dd': 165,
#  '##ved': 448,
#  'ms': 385,
#  'eula': 511,
#  'f': 35,
#  '##rent': 135,
#  'write': 539,
#  '##gth': 117,
#  '6': 23,
#  'lit': 271,
#  'software': 256,
#  '##ription': 323,
#  'cor': 266,
#  'only': 498,
#  '##viou': 449,
#  'necessary': 543,
#  'directory': 486,
#  'sy': 401,
#  'on': 275,
#  '##rectory': 464,
#  '##sc': 295,
#  '##mment': 431,
#  '##urce': 459,
#  'system': 551,
#  'a': 30,
#  'release': 320,
#  '##20': 302,
#  'rtos': 398,
#  '##oft': 167,
#  'tx': 405,
#  '16': 122,
#  'soft': 234}

# %%
# now, let's tokenize a simple C program: 
strCProgram = '''
int main(int argc, void **argc)
{
  printf("%s", "Hello World\n");
  return 0; 
}
'''

# %%
# now, let's see how the tokenizer works
# we invoke it based on the program above
tokenizedText = tokenizer.encode(strCProgram)

# and explore what this tokenized text object contains
tokenizedText
# Out:
# Encoding(num_tokens=50, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])

# %%
# and we can also see how the input program was actually tokenized
tokenizedText.tokens
# Out:
# ['in',
#  '##t',
#  'ma',
#  '##in',
#  '(',
#  'in',
#  '##t',
#  'a',
#  '##r',
#  '##g',
#  '##c',
#  ',',
#  'v',
#  '##o',
#  '##i',
#  '##d',
#  '*',
#  '*',
#  'a',
#  '##r',
#  '##g',
#  '##c',
#  ')',
#  '{',
#  'p',
#  '##ri',
#  '##n',
#  '##t',
#  '##f',
#  '(',
#  '"',
#  '[UNK]',
#  's',
#  '"',
#  ',',
#  '"',
#  'h',
#  '##e',
#  '##ll',
#  '##o',
#  'wor',
#  '##l',
#  '##d',
#  '"',
#  ')',
#  ';',
#  'return',
#  '0',
#  ';',
#  '}']

# %%
tokenizedText.ids
# Out:
# [110,
#  57,
#  272,
#  104,
#  10,
#  110,
#  57,
#  30,
#  61,
#  63,
#  69,
#  14,
#  49,
#  58,
#  62,
#  72,
#  12,
#  12,
#  30,
#  61,
#  63,
#  69,
#  11,
#  54,
#  44,
#  204,
#  68,
#  57,
#  76,
#  10,
#  6,
#  1,
#  46,
#  6,
#  14,
#  6,
#  37,
#  66,
#  183,
#  58,
#  108,
#  70,
#  72,
#  6,
#  11,
#  26,
#  343,
#  18,
#  26,
#  56]

# %% [markdown]
# ## BPE - Byte Pair Encoding
#
# In this part of the workbook, we use the same program text, but we train another tokenizer.

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE

# First, we instantiate the tokenizer 
tokenizer = Tokenizer(BPE(unk_token="[UNK]"))

# %%
# in the next step, we instantiate a trainer
# which is hugging face's way of training elements
from tokenizers.trainers import BpeTrainer

trainer = BpeTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"])

from tokenizers.pre_tokenizers import Whitespace

tokenizer.pre_tokenizer = Whitespace()

# %%
# and finally, we train the tokenizer
# as the training set, we use the very same file as previously
tokenizer.train([paths], trainer)

# %%
# we can print the vocabulary
tokenizer.get_vocab()
# Out:
# {'be': 500,
#  'g_temp': 201,
#  '>': 28,
#  'ICMP': 182,
#  'll': 235,
#  'w': 74,
#  '[PAD]': 3,
#  'Software': 490,
#  'ment': 286,
#  'UCHA': 223,
#  'ines': 589,
#  '********************************': 105,
#  'tw': 547,
#  'DESCR': 405,
#  'EU': 464,
#  'wh': 371,
#  'these': 378,
#  '/*': 85,
#  'IP': 325,
#  'End': 322,
#  'computed': 595,
#  '_': 53,
#  'Term': 492,
#  'Corporation': 436,
#  'NX_CHA': 383,
#  'ry': 538,
#  '=': 27,
#  'st': 191,
#  'FU': 465,
#  'ET': 320,
#  'comment': 587,
#  'NX_DISABLE_ICMP': 428,
#  'K': 38,
#  'ed': 134,
#  'cre': 349,
#  'ter': 150,
#  '*(': 444,
#  'define': 602,
#  '(': 10,
#  'current_packet': 168,
#  'nx_api': 594,
#  'Mic': 220,
#  'lied': 522,
#  'padd': 536,
#  'u': 72,
#  'compute': 252,
#  'logic': 403,
#  '_ptr': 104,
#  'Mu': 475,
#  'RCE_CODE': 641,
#  'SCR': 338,
#  'OUTPUT': 638,
#  'NAME': 637,
#  'nd': 203,
#  'eturn': 426,
#  'CE_': 459,
#  'CK': 215,
#  'are': 228,
#  'ointer': 170,
#  'to': 136,
#  'C': 31,
#  'operation': 601,
#  'Cor': 318,
#  'etur': 375,
#  '1': 19,
#  '9': 24,
#  'X': 50,
#  'text': 556,
#  'NX_SOURCE_CODE': 667,
#  'need': 394,
#  'We': 341,
#  'previous': 678,
#  '_ICMP': 343,
#  'HOR': 468,
#  ')': 11,
#  '/********************************': 153,
#  'by': 200,
#  'resulting': 666,
#  'oin': 161,
#  'f': 59,
#  'iou': 520,
#  'input': 555,
#  'first': 599,
#  'case': 506,
#  'Multi': 635,
#  'routines': 668,
#  'Zh': 274,
#  'CR': 317,
#  'alignment': 434,
#  'ASE': 396,
#  'b': 55,
#  'Pickup': 415,
#  '_16_MAS': 248,
#  'Pro': 482,
#  'n': 66,
#  'CODE': 623,
#  'nment': 360,
#  'bound': 501,
#  'flow': 515,
#  '_nx_icmp': 345,
#  't': 71,
#  'xt': 205,
#  'version': 609,
#  'v': 73,
#  'USHORT_ENDIAN': 586,
#  'en': 91,
#  'fro': 513,
#  'Return': 485,
#  'por': 361,
#  'lower': 613,
#  '****': 82,
#  'lon': 202,
#  'necessary': 669,
#  'under': 663,
#  '3': 21,
#  'HIST': 630,
#  '(!': 441,
#  'ELE': 321,
#  'L': 39,
#  '05': 447,
#  'supp': 559,
#  'packet': 107,
#  '&': 8,
#  'Yu': 273,
#  'viou': 552,
#  'E': 33,
#  'nx_packet_prepend_ptr': 432,
#  'Compon': 624,
#  'DIAN': 250,
#  'OS': 330,
#  'least': 584,
#  'LO': 117,
#  'AzureRTOS_EULA': 671,
#  'AUT': 454,
#  'V': 48,
#  ',': 14,
#  'Mask': 634,
#  'cros': 281,
#  'sed': 366,
#  'return': 540,
#  'TION': 306,
#  'I': 37,
#  'lti': 606,
#  'ved': 551,
#  'nx_packet_last': 392,
#  'E_': 267,
#  'Az': 315,
#  'Net': 477,
#  'ent': 122,
#  '_ENDIAN': 258,
#  'Full': 629,
#  'LICENSE': 632,
#  'star': 588,
#  'one': 293,
#  '******************************************/': 165,
#  'AUTHOR': 622,
#  'Licen': 473,
#  '_checksum': 342,
#  'end': 130,
#  'O': 42,
#  'sion': 390,
#  '_compute': 344,
#  'toco': 574,
#  'word_ptr': 137,
#  'DI': 186,
#  'OUT': 481,
#  '16': 127,
#  'ECK': 323,
#  'it': 147,
#  'lo': 236,
#  'ain': 499,
#  'ary': 401,
#  'rights': 616,
#  'nx_packet_': 151,
#  'syste': 659,
#  'or': 97,
#  'r': 69,
#  ')(': 442,
#  'include': 380,
#  'cal': 504,
#  'RCE_': 487,
#  'NX_LO': 243,
#  'NX_DISABLE_ICMP_RX_CHECKSUM': 619,
#  'Con': 458,
#  'NX_DI': 382,
#  'te': 96,
#  'ak': 498,
#  'software': 367,
#  '********': 83,
#  'message': 526,
#  'se': 148,
#  'ft': 510,
#  'nx_icmp': 302,
#  'de': 158,
#  'fi': 283,
#  'nx_packet_length': 579,
#  'cess': 507,
#  'ute': 240,
#  'che': 100,
#  'p': 68,
#  '{': 78,
#  '6': 23,
#  'SU': 336,
#  '**': 81,
#  'uct': 550,
#  'Message': 476,
#  'carry': 651,
#  'yright': 553,
#  'RELE': 335,
#  'cur': 142,
#  'H': 36,
#  'ecified': 352,
#  'ros': 180,
#  'again': 597,
#  'if': 126,
#  'This': 419,
#  'LIC': 472,
#  'AL': 314,
#  'reser': 567,
#  '[MASK]': 4,
#  'word': 111,
#  'ot': 530,
#  'nx': 118,
#  'reserved': 665,
#  'RTOS': 416,
#  'nx_packet': 138,
#  'None': 329,
#  'packet_ptr': 166,
#  'itial': 389,
#  'rosoft': 249,
#  '_EN': 225,
#  'D': 32,
#  'DESCRIPTION': 435,
#  'NX_LITTLE_ENDIAN': 430,
#  'bits': 251,
#  'TIO': 272,
#  '20': 211,
#  'A': 29,
#  'Th': 339,
#  'Ver': 495,
#  'SE': 488,
#  'mpon': 564,
#  'last': 285,
#  '&&': 440,
#  'SABLE_ICMP': 418,
#  'UCHAR': 256,
#  'str': 544,
#  'NX_CHANGE_': 429,
#  '_checksum_compute': 421,
#  'FT': 268,
#  'X_CHECKSUM': 437,
#  'licen': 358,
#  'aka': 647,
#  'https': 600,
#  '****************': 88,
#  'ig': 231,
#  'IT': 326,
#  'ou': 189,
#  'oftware': 300,
#  'pp': 533,
#  'TX_CHECKSUM': 493,
#  '/**************************************************************************/': 169,
#  'Azure': 410,
#  'for': 512,
#  'NCTION': 479,
#  'AS': 185,
#  'necess': 582,
#  'we': 290,
#  'ied': 234,
#  'padding': 658,
#  'oft': 179,
#  'l': 64,
#  'ol': 529,
#  '://': 451,
#  '_p': 90,
#  'Initialize': 612,
#  'over': 532,
#  'at': 157,
#  '*': 12,
#  'def': 299,
#  'USH': 173,
#  ');': 124,
#  '|': 79,
#  'ined': 379,
#  'USHORT': 183,
#  'else': 423,
#  'nx_packet_next': 391,
#  'there': 377,
#  'ENSE': 590,
#  'Modified': 593,
#  'ize': 518,
#  'AzureRTOS': 615,
#  'op': 287,
#  'y': 76,
#  'ile': 519,
#  'add': 278,
#  'ver': 370,
#  'IO': 269,
#  'ic': 128,
#  'low': 402,
#  'ap': 146,
#  'length': 123,
#  'sk': 541,
#  'ternet': 578,
#  'licensed': 608,
#  'RELEASE': 417,
#  'c': 56,
#  'on': 114,
#  '*((': 263,
#  'dified': 509,
#  'a': 54,
#  'append_ptr': 245,
#  '*/': 84,
#  'ar': 227,
#  'si': 149,
#  'have': 354,
#  'boundary': 648,
#  'NX_SOU': 569,
#  'et': 89,
#  'single': 661,
#  'trol': 560,
#  'DAT': 463,
#  'tr': 99,
#  'AB': 265,
#  'HISTORY': 673,
#  'IC': 155,
#  'icen': 296,
#  '.': 16,
#  '++': 445,
#  'le': 176,
#  '_16': 174,
#  'supplied': 664,
#  'ro': 135,
#  'ULONG': 139,
#  '09': 448,
#  'PACK': 333,
#  'ude': 289,
#  'R': 44,
#  'U': 47,
#  'NX_LOWER_16_MASK': 262,
#  'funct': 653,
#  'api': 577,
#  't_temp': 239,
#  'k': 63,
#  'es': 282,
#  '->': 131,
#  'upper': 395,
#  'next': 247,
#  'Add': 213,
#  'structure': 680,
#  'short_temp': 260,
#  'rect': 566,
#  'ht': 284,
#  'swap': 259,
#  'Det': 216,
#  'into': 241,
#  'zer': 373,
#  'DE': 266,
#  'Ma': 474,
#  'size': 181,
#  'CALLS': 603,
#  'ms': 524,
#  'checksu': 102,
#  'ly': 521,
#  'ware': 291,
#  'Lo': 471,
#  'rst': 539,
#  'nx_': 244,
#  'LA': 469,
#  'len': 121,
#  'ping': 363,
#  'LS': 470,
#  "'": 9,
#  'NX_SHIFT_BY': 311,
#  'system': 679,
#  'root': 573,
#  'direct': 652,
#  'an': 133,
#  'X_CH': 381,
#  'NG': 125,
#  'in': 95,
#  'file': 407,
#  'Loop': 631,
#  'up': 178,
#  'Wr': 496,
#  'age': 406,
#  'NX_PACK': 385,
#  'this': 570,
#  'sy': 542,
#  'ase': 277,
#  'of': 106,
#  'defined': 408,
#  're': 115,
#  'Yuxin': 307,
#  'ABLE': 303,
#  '//': 446,
#  'from': 654,
#  'the': 94,
#  'SOU': 491,
#  '[UNK]': 0,
#  'NX_PACKET': 431,
#  'Write': 645,
#  'ste': 543,
#  'BY': 214,
#  'ck': 86,
#  'th': 119,
#  'ial': 355,
#  'gic': 353,
#  '+': 13,
#  'start': 670,
#  'pre': 535,
#  'm': 65,
#  'Microsoft': 255,
#  'NX_LOWER_16_MAS': 261,
#  'INPUT': 605,
#  'gth': 120,
#  'nct': 528,
#  'X_': 109,
#  'result': 568,
#  'ULO': 132,
#  'ACK': 316,
#  '>>': 264,
#  'late': 523,
#  'endif': 571,
#  '_nx_icmp_checksum_compute': 422,
#  'ULONG_ENDIAN': 575,
#  'lt': 357,
#  'eration': 562,
#  '((': 171,
#  'ur': 129,
#  'ermine': 253,
#  'B': 30,
#  'g': 60,
#  '/**': 197,
#  'shor': 238,
#  'RT': 334,
#  'generate': 655,
#  'ECKSU': 413,
#  'xin': 292,
#  'Set': 271,
#  'erate': 563,
#  'N': 41,
#  'IPTION': 414,
#  'ation': 298,
#  'IN': 324,
#  'icmp': 297,
#  'ut': 369,
#  'CO': 456,
#  'ne': 160,
#  'tps': 548,
#  '2020': 399,
#  '_EU': 497,
#  'clude': 309,
#  'Control': 625,
#  'mpute': 242,
#  'ound': 397,
#  'd': 57,
#  '-': 15,
#  'license': 607,
#  'nx_packet_pre': 388,
#  'ps': 534,
#  'ER': 217,
#  '[SEP]': 2,
#  '!=': 439,
#  '))': 195,
#  'pend': 190,
#  'All': 455,
#  '[CLS]': 1,
#  'ine': 192,
#  'generates': 677,
#  'zero': 425,
#  'CH': 154,
#  'net': 527,
#  'In': 218,
#  '30': 450,
#  'ORY': 576,
#  'long_temp': 210,
#  'ckup': 374,
#  'cu': 502,
#  'Move': 301,
#  'ure': 288,
#  'Z': 52,
#  'CTION': 461,
#  'CAL': 319,
#  'left': 585,
#  'Initial': 400,
#  'PORTABLE': 640,
#  'TLE': 340,
#  'If': 327,
#  'AT': 453,
#  'previou': 657,
#  'UIN': 494,
#  'culate': 649,
#  '),': 443,
#  'SABLE': 337,
#  'MAS': 221,
#  'MP': 172,
#  'acros': 348,
#  'Corpor': 411,
#  '>=': 313,
#  'Do': 462,
#  ':': 25,
#  'crossed': 598,
#  'decrease': 433,
#  'AN': 212,
#  'sizeof': 184,
#  'ag': 276,
#  'CALLED': 604,
#  'Component': 672,
#  'ave': 347,
#  'z': 77,
#  'ian': 233,
#  'right': 424,
#  'ORT': 167,
#  'Zhou': 308,
#  'gen': 516,
#  '0': 18,
#  'directory': 675,
#  'UT': 222,
#  'NX_CHANGE_ULONG_ENDIAN': 617,
#  'sw': 237,
#  'e': 58,
#  'ct': 280,
#  'M': 40,
#  'NGE_': 386,
#  'Fu': 466,
#  'will': 372,
#  'hor': 230,
#  'current': 144,
#  'di': 508,
#  'Copyright': 626,
#  'Cop': 460,
#  'ack': 92,
#  '2': 20,
#  'NX_SH': 294,
#  'S': 45,
#  '!': 5,
#  'function': 676,
#  'OR': 140,
#  'NAM': 478,
#  'alig': 398,
#  'dd': 175,
#  'two': 662,
#  'ill': 356,
#  '_te': 145,
#  'CHA': 193,
#  'NX_CHANGE_USHORT_ENDIAN': 618,
#  '_BY': 275,
#  'mment': 525,
#  'EN': 198,
#  'byte': 209,
#  'pecified': 364,
#  '**********/': 164,
#  'essage': 409,
#  'TLE_ENDIAN': 420,
#  'P': 43,
#  'nx_packet_append_ptr': 246,
#  'Co': 457,
#  'car': 505,
#  'LIT': 328,
#  'h': 61,
#  '(((': 583,
#  'ze': 162,
#  'and': 208,
#  'ory': 557,
#  'erm': 207,
#  'NX_DISABLE_ICMP_TX_CHECKSUM': 620,
#  ';': 26,
#  'o': 67,
#  'while': 610,
#  'mp': 113,
#  'rig': 365,
#  'overflow': 656,
#  'al': 199,
#  'NetX': 636,
#  '#': 7,
#  'el': 351,
#  'sing': 546,
#  'Mo': 219,
#  'ST': 489,
#  'ion': 232,
#  'Protocol': 674,
#  'he': 87,
#  '*)': 196,
#  'rout': 572,
#  'new': 581,
#  'UINT': 643,
#  'G': 35,
#  'pointer': 177,
#  'Setup': 305,
#  'fu': 511,
#  'NX_DISABLE_ICMP_': 438,
#  '_MAS': 226,
#  '_pre': 376,
#  'OU': 480,
#  'swapping': 404,
#  've': 204,
#  '**/': 163,
#  '++;': 621,
#  'computes': 596,
#  'Endian': 412,
#  'Version': 644,
#  'und': 549,
#  'WER': 224,
#  'Protoco': 639,
#  '_EULA': 646,
#  'cified': 350,
#  'T': 46,
#  'co': 188,
#  'LED': 580,
#  'Determine': 254,
#  'W': 49,
#  'macros': 359,
#  'NX_LIT': 384,
#  'Terms': 642,
#  'sult': 558,
#  'calculate': 650,
#  'acket': 93,
#  'found': 514,
#  'er': 112,
#  'whole': 611,
#  'RX_CHECKSUM': 486,
#  'off': 561,
#  '||': 554,
#  '"': 6,
#  'ess': 310,
#  'files': 614,
#  'HI': 467,
#  'su': 98,
#  'PUT': 332,
#  'bit': 187,
#  'endian': 387,
#  'cl': 279,
#  'AM': 452,
#  'ite': 517,
#  'ser': 545,
#  'ing': 206,
#  'struct': 660,
#  'DATE': 627,
#  'cksu': 101,
#  'ole': 531,
#  'IFT': 270,
#  'specified': 368,
#  'NX_': 116,
#  'ast': 229,
#  'i': 62,
#  'wor': 110,
#  'SH': 141,
#  '_packet': 108,
#  'License': 633,
#  'PORT': 483,
#  'FUNCTION': 628,
#  'LE': 156,
#  'IFT_BY': 304,
#  'pend_ptr': 194,
#  'Include': 591,
#  'WER_16_MAS': 257,
#  's': 70,
#  'Pointer': 484,
#  '_temp': 152,
#  'Internet': 592,
#  'rent': 143,
#  'decre': 393,
#  'ate': 346,
#  'can': 503,
#  'F': 34,
#  'checksum': 103,
#  'per': 362,
#  '19': 449,
#  'X_CHECKSU': 427,
#  'x': 75,
#  'Pi': 331,
#  'only': 565,
#  'Y': 51,
#  'is': 159,
#  '5': 22,
#  'NX_SHIFT_BY_16': 312,
#  'put': 537,
#  '}': 80,
#  'ified': 295,
#  '/': 17}

# %%
# and we can encode the text
tokenizedText = tokenizer.encode(strCProgram)

tokenizedText.tokens
# Out:
# ['in',
#  't',
#  'm',
#  'ain',
#  '(',
#  'in',
#  't',
#  'ar',
#  'g',
#  'c',
#  ',',
#  'v',
#  'o',
#  'i',
#  'd',
#  '**',
#  'ar',
#  'g',
#  'c',
#  ')',
#  '{',
#  'p',
#  'r',
#  'in',
#  't',
#  'f',
#  '(',
#  '"',
#  '[UNK]',
#  's',
#  '"',
#  ',',
#  '"',
#  'H',
#  'e',
#  'll',
#  'o',
#  'W',
#  'or',
#  'l',
#  'd',
#  '"',
#  ');',
#  'return',
#  '0',
#  ';',
#  '}']

# %%
tokenizedText.ids
# Out:
# [95,
#  71,
#  65,
#  499,
#  10,
#  95,
#  71,
#  227,
#  60,
#  56,
#  14,
#  73,
#  67,
#  62,
#  57,
#  81,
#  227,
#  60,
#  56,
#  11,
#  78,
#  68,
#  69,
#  95,
#  71,
#  59,
#  10,
#  6,
#  0,
#  70,
#  6,
#  14,
#  6,
#  36,
#  58,
#  235,
#  67,
#  49,
#  97,
#  64,
#  57,
#  6,
#  124,
#  540,
#  18,
#  26,
#  80]
