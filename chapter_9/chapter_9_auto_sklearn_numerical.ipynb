# %% [markdown]
# # Using auto-sklearn for numerical data
#
# In this workbook, we use the auto-sklearn machine learning model to find the best model for the defect data from the previous chapters.

# %%
# !pip install -q auto-sklearn

# %%
# !pip install -q openpyxl

# %%
# read the file with data using openpyxl
import pandas as pd

# we read the data from the excel file, 
# which is the defect data from the ant 1.3 system
dfDataCamel12 = pd.read_excel('./chapter_6_dataset_numerical.xlsx', 
                            sheet_name='camel_1_2',
                            index_col=0)

# %%
dfDataCamel12
# Out:
#                                              CBO  DCC  ExportCoupling  \
# ClassName
# org.apache.camel.AlreadyStoppedException       1    0               1
# org.apache.camel.AsyncCallback                 8    0              12
# org.apache.camel.AsyncProcessor               10    2              12
# org.apache.camel.Body                          0    0               0
# org.apache.camel.CamelContext                 27    9              47
# ...                                          ...  ...             ...
# org.apache.camel.util.jndi.JndiContext         4    1               1
# org.apache.camel.view.GraphGeneratorSupport    9    4               2
# org.apache.camel.view.NodeData                 8    0               3
# org.apache.camel.view.RouteDotGenerator        5    4               0
# org.apache.camel.view.XmlGraphGenerator        5    3               0
#
#                                              ImportCoupling  NOM  WMC  Defect
# ClassName
# org.apache.camel.AlreadyStoppedException                  0    0    0       1
# org.apache.camel.AsyncCallback                            0    1    1       1
# org.apache.camel.AsyncProcessor                           2    1    1       1
# org.apache.camel.Body                                     0    0    0       0
# org.apache.camel.CamelContext                             9   17   17       1
# ...                                                     ...  ...  ...     ...
# org.apache.camel.util.jndi.JndiContext                    3   35   73       1
# org.apache.camel.view.GraphGeneratorSupport               8   10   23       0
# org.apache.camel.view.NodeData                            5    2    6       1
# org.apache.camel.view.RouteDotGenerator                   6    5    7       0
# org.apache.camel.view.XmlGraphGenerator                   5    7   30       0
#
# [368 rows x 7 columns]

# %%
# prepare the dataset
import sklearn.model_selection

X = dfDataCamel12.drop(['Defect'], axis=1)
y = dfDataCamel12.Defect

X_train, X_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(X, y, random_state=42, train_size=0.9)

# %%
import autosklearn.classification
cls = autosklearn.classification.AutoSklearnClassifier()
cls.fit(X_train, y_train)
predictions = cls.predict(X_test)

# %%
# now we can get the best models with their weights
cls.leaderboard()
# Out:
#           rank  ensemble_weight           type      cost  duration
# model_id
# 431          1             0.02  random_forest  0.209091  1.022652
# 473         29             0.02  random_forest  0.209091  1.185152
# 498         28             0.02  random_forest  0.209091  1.082618
# 511         27             0.02  random_forest  0.209091  0.994516
# 518         26             0.02  random_forest  0.209091  1.047253
# 529         25             0.02  random_forest  0.209091  1.005801
# 530         24             0.02  random_forest  0.209091  0.994972
# 552         23             0.04  random_forest  0.209091  1.000448
# 571         22             0.02  random_forest  0.209091  0.987272
# 598         21             0.04  random_forest  0.209091  0.976980
# 605         20             0.02  random_forest  0.209091  0.968073
# 613         19             0.02  random_forest  0.209091  1.147304
# 624         18             0.02  random_forest  0.209091  0.991816
# 634         17             0.02  random_forest  0.209091  1.008555
# 640         30             0.02  random_forest  0.209091  0.971541
# 646         16             0.04  random_forest  0.209091  0.981240
# 651         14             0.02  random_forest  0.209091  0.971779
# 658         13             0.02  random_forest  0.209091  0.986351
# 664         12             0.02  random_forest  0.209091  1.113425
# 675         11             0.04  random_forest  0.209091  0.974560
# 684         10             0.06  random_forest  0.209091  0.988066
# 688          9             0.04  random_forest  0.209091  1.011925
# 691          8             0.06  random_forest  0.209091  0.976696
# 692          7             0.02  random_forest  0.209091  0.986983
# 700          6             0.06  random_forest  0.209091  0.973121
# 703          5             0.08  random_forest  0.209091  0.964903
# 724          4             0.06  random_forest  0.209091  0.977685
# 743          3             0.04  random_forest  0.209091  1.003171
# 750          2             0.02  random_forest  0.209091  0.995982
# 752         15             0.02  random_forest  0.209091  0.992578
# 762         31             0.06  random_forest  0.209091  1.003483

# %%
# and we can even take a look at the best models' scores
ensemble_dict = cls.show_models()
print(ensemble_dict)
# Out:
# {431: {'model_id': 431, 'rank': 1, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f438b5c4160>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43893eb6a0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43893eb070>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 473: {'model_id': 473, 'rank': 2, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f438b5c4f10>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4389218c40>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4389398550>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 498: {'model_id': 498, 'rank': 3, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f438927f6a0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43894344c0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43893a6d60>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=8, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 511: {'model_id': 511, 'rank': 4, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f43893c1610>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f438917c190>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4389165df0>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 518: {'model_id': 518, 'rank': 5, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f438926ea30>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4388fb1d00>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43892be100>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 529: {'model_id': 529, 'rank': 6, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f43891c05b0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43891e4550>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4388d0d730>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=3,
#                        min_samples_split=13, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 530: {'model_id': 530, 'rank': 7, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f438915b580>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f438928e940>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43894417c0>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=3,
#                        min_samples_split=13, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 552: {'model_id': 552, 'rank': 8, 'cost': 0.2090909090909091, 'ensemble_weight': 0.04, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f438916ffd0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43891d4e80>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43891d4400>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 571: {'model_id': 571, 'rank': 9, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4389262850>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4375fb0a60>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4375f4d340>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 598: {'model_id': 598, 'rank': 10, 'cost': 0.2090909090909091, 'ensemble_weight': 0.04, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4388d334c0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4375d38520>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4375d38dc0>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 605: {'model_id': 605, 'rank': 11, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4388f9ea60>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4375c42d60>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4375af1640>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 613: {'model_id': 613, 'rank': 12, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4375eaf5e0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4375a2bf70>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4375b23f40>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 624: {'model_id': 624, 'rank': 13, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4375ca3f40>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43757b51c0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43757b5a60>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 634: {'model_id': 634, 'rank': 14, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4375af97c0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43756b7a00>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43756572e0>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 640: {'model_id': 640, 'rank': 15, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4375942280>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43754434c0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4375443d60>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 646: {'model_id': 646, 'rank': 16, 'cost': 0.2090909090909091, 'ensemble_weight': 0.04, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f437578ebe0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f437534bd00>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f437522d700>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=3,
#                        min_samples_split=8, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 651: {'model_id': 651, 'rank': 17, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f437555f580>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43750d07c0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43750450a0>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 658: {'model_id': 658, 'rank': 18, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f43753a9ee0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4374ec0160>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4374ec0a00>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 664: {'model_id': 664, 'rank': 19, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f43751f8880>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4374dc39a0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4374cdc280>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=10, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 675: {'model_id': 675, 'rank': 20, 'cost': 0.2090909090909091, 'ensemble_weight': 0.04, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4375049220>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4374b4e460>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4374b4ed00>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 684: {'model_id': 684, 'rank': 21, 'cost': 0.2090909090909091, 'ensemble_weight': 0.06, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4374e95b80>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4374a54ca0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43749376a0>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 688: {'model_id': 688, 'rank': 22, 'cost': 0.2090909090909091, 'ensemble_weight': 0.04, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4374c68520>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43747d1790>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f437474f070>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 691: {'model_id': 691, 'rank': 23, 'cost': 0.2090909090909091, 'ensemble_weight': 0.06, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4374ab2e80>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43745ca130>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43745ca9d0>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 692: {'model_id': 692, 'rank': 24, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f43748fd820>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43744d1970>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43743e9250>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 700: {'model_id': 700, 'rank': 25, 'cost': 0.2090909090909091, 'ensemble_weight': 0.06, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f43747531f0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4374257430>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4374257cd0>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 703: {'model_id': 703, 'rank': 26, 'cost': 0.2090909090909091, 'ensemble_weight': 0.08, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4374520b50>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43740dcc70>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f437403e670>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 724: {'model_id': 724, 'rank': 27, 'cost': 0.2090909090909091, 'ensemble_weight': 0.06, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f43743704f0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4373e64730>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4373e64fd0>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 743: {'model_id': 743, 'rank': 28, 'cost': 0.2090909090909091, 'ensemble_weight': 0.04, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f43741bce50>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4373d32e50>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4373cd8730>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 750: {'model_id': 750, 'rank': 29, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f437400a7f0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f4373b5d5b0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f4373b5de50>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 752: {'model_id': 752, 'rank': 30, 'cost': 0.2090909090909091, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4373e58e50>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43739c4fa0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f43738e1760>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 762: {'model_id': 762, 'rank': 31, 'cost': 0.2090909090909091, 'ensemble_weight': 0.06, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f4373c285b0>, 'balancing': Balancing(random_state=1, strategy='weighting'), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f43737e99d0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f437374a370>, 'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        min_samples_split=14, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}}

# %%
# and print the accuracy score
print(f"Accuracy score {sklearn.metrics.accuracy_score(y_test, predictions):.2f}")
# Out:
# Accuracy score 0.59

# %%
# and print the statistics for the model
print(cls.sprint_statistics())
# Out:
# auto-sklearn results:
#   Dataset name: 4b131006-f653-11ed-814a-00155de31e8a
#   Metric: accuracy
#   Best validation score: 0.790909
#   Number of target algorithm runs: 1273
#   Number of successful target algorithm runs: 1214
#   Number of crashed target algorithm runs: 59
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 0
